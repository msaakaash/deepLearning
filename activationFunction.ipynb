# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Sigmoid

# %%
def sigmoid(x):
  return 1/(1+np.exp(-x))

# %%
def derivative_sigmoid(y):
  return sigmoid(y)*sigmoid(1-y)

# %%
sigmoid(1)
# Out:
# 0.7310585786300049

# %%
def plot_sigmoid():
  x = np.linspace(-10,10,100)
  y = sigmoid(x)
  plt.plot(x,y)
  plt.title("Sigmoid Function")
  plt.xlabel("Input")
  plt.ylabel("Output")
  plt.show()

  z = derivative_sigmoid(x)
  plt.plot(x,z)
  plt.title("Derivative")
  plt.xlabel("Input")
  plt.ylabel("Output")
  plt.show()
plot_sigmoid()

# %% [markdown]
# ### Tanh

# %%
def tanh(x):
  return ((np.exp(x)-np.exp(-x)))/(np.exp(x)+np.exp(-x))

# %%
tanh(-56)
# Out:
# -1.0

# %%
def derivative_tanh(x):
  return 1-tanh(x)**2

# %%
def plot_tanh():
  x = np.linspace(-10,10,100)
  y = tanh(x)
  plt.plot(x,y)
  plt.title("Tanh Function")
  plt.xlabel("Input")
  plt.ylabel("Output")
  plt.show()

  z =  derivative_tanh(x)
  plt.plot(x,z)
  plt.title("Derivative")
  plt.xlabel("Input")
  plt.ylabel("Output")
  plt.show()
plot_tanh()

# %% [markdown]
# ### Relu

# %%
def relu(x):
  return np.maximum(0,x)

# %%
def derivative_relu(x):
  return np.where(x > 0, 1, 0)

# %%
def plot_relu():
  x = np.linspace(-10,10,100)
  y = relu(x)
  plt.plot(x,y)
  plt.title("Relu Function")
  plt.xlabel("Input")
  plt.ylabel("Output")
  plt.show()

  z= derivative_relu(x)
  plt.plot(x,z)
  plt.title("Derivative")
  plt.xlabel("Input")
  plt.ylabel("Output")
  plt.show()
plot_relu()

# %% [markdown]
# ### Leaky Relu

# %%
def lrelu(x,alp=0.1):
  return np.maximum(alp*x,x)

# %%
def derivative_lrelu(x,alp=0.1):
  return np.where(x > 0,1, alp)

# %%
def plot_lrelu():
  x = np.linspace(-10,10,100)
  y = lrelu(x)
  plt.plot(x,y)
  plt.title("Leaky relu Function")
  plt.xlabel("Input")
  plt.ylabel("Output")
  plt.show()


  z = derivative_lrelu(x)
  plt.plot(x,z)
  plt.title("Derivative")
  plt.xlabel("Input")
  plt.ylabel("Output")
  plt.show()
plot_lrelu()

# %% [markdown]
# ### ELU

# %%
def elu(x,alpha=1):
  return np.where(x > 0, x, alpha * (np.exp(x) - 1))

# %%
def derivative_relu(x,alpha=1):
  return np.where(x > 0, 1, alpha + elu(x))

# %%
def plot_elu():
  x = np.linspace(-10,10,100)
  y = elu(x)
  plt.plot(x,y)
  plt.title("Elu Function")
  plt.xlabel("Input")
  plt.ylabel("Output")
  plt.show()

  z = derivative_relu(x)
  plt.plot(x,z)
  plt.title("Derivative")
  plt.xlabel("Input")
  plt.ylabel("Output")
  plt.show()
plot_elu()

# %% [markdown]
# ### Soft Max

# %%
def softmax(x):
  x_shifted = x - np.max(x)
  exp_x = np.exp(x_shifted)
  return exp_x / np.sum(exp_x)

# %%
def plot_sof():
  x = np.linspace(-10,10,100)
  y = elu(x)
  plt.plot(x,y)
  plt.title("SoftMax Function")
  plt.xlabel("Input")
  plt.ylabel("Output")
  plt.show()
plot_sof()

# %%
def softplus(x):
  return np.log(1+np.exp(x))

# %%
def derivative_softplus(x):
  return 1/(1+np.exp(-x))

# %%
def plot_sof():
  x = np.linspace(-10,10,100)
  y = softmax(x)
  plt.plot(x,y)
  plt.title("Softplus Function")
  plt.xlabel("Input")
  plt.ylabel("Output")
  plt.show()


  z=derivative_softplus(x)
  plt.plot(x,z)
  plt.title("Derivative")
  plt.xlabel("Input")
  plt.ylabel("Output")
  plt.show()
plot_sof()
